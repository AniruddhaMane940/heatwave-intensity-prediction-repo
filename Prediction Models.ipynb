# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("com_data.csv")

# %%
df
# Out:
#       District       Time  Temperature in deg  Temperature in fer  \
# 0     Adilabad   4/1/2016                  38               100.4
# 1     Adilabad   4/2/2016                  40               104.0
# 2     Adilabad   4/3/2016                  41               105.8
# 3     Adilabad   4/4/2016                  41               105.8
# 4     Adilabad   4/5/2016                  37                98.6
# ...        ...        ...                 ...                 ...
# 9130  Warangal  9/26/2020                  25                77.0
# 9131  Warangal  9/27/2020                  26                78.8
# 9132  Warangal  9/28/2020                  27                80.6
# 9133  Warangal  9/29/2020                  28                82.4
# 9134  Warangal  9/30/2020                  27                80.6
#
#       Dew Point in Deg  Dew Point in fer  Humidity  Wind Speed      Pressure  \
# 0                   -2              28.4        11    8 | 4.97  29.77 | 1008
# ...

# %% [markdown]
# # Exploratory data analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9135 entries, 0 to 9134
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   District            9135 non-null   object
#  1   Time                9135 non-null   object
#  2   Temperature in deg  9135 non-null   int64
#  3   Temperature in fer  9135 non-null   float64
#  4   Dew Point in Deg    9135 non-null   int64
#  5   Dew Point in fer    9135 non-null   float64
#  6   Humidity            9135 non-null   int64
#  7   Wind Speed          9135 non-null   object
#  8   Pressure            9135 non-null   object
#  9   Precipitation       9135 non-null   object
#  10  R                   9135 non-null   float64
#  11  Relative Humidity   9135 non-null   float64
#  12  Heat Index          9135 non-null   float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 927.9+ KB

# %%
df.describe()
# Out:
#        Temperature in deg  Temperature in fer  Dew Point in Deg  \
# count         9135.000000         9135.000000       9135.000000
# mean            30.151724           86.273103         15.454297
# std              5.139692            9.251446          6.425575
# min             17.000000           62.600000        -10.000000
# 25%             26.000000           78.800000         11.000000
# 50%             29.000000           84.200000         16.000000
# 75%             34.000000           93.200000         22.000000
# max             44.000000          111.200000         25.000000
#
#        Dew Point in fer     Humidity            R  Relative Humidity  \
# count       9135.000000  9135.000000  9135.000000        9135.000000
# mean          59.817734    52.774603     1.046144          46.728183
# std           11.566034    22.244036     0.418476          22.004753
# min           14.000000     6.000000    -0.760458           4.302429
# ...

# %%
df.corr()
# Out:
#                     Temperature in deg  Temperature in fer  Dew Point in Deg  \
# Temperature in deg            1.000000            1.000000         -0.213985
# Temperature in fer            1.000000            1.000000         -0.213985
# Dew Point in Deg             -0.213985           -0.213985          1.000000
# Dew Point in fer             -0.213985           -0.213985          1.000000
# Humidity                     -0.638061           -0.638061          0.857685
# R                            -0.211355           -0.211355          0.999615
# Relative Humidity            -0.625904           -0.625904          0.855665
# Heat Index                    0.924623            0.924623          0.084861
#
#                     Dew Point in fer  Humidity         R  Relative Humidity  \
# Temperature in deg         -0.213985 -0.638061 -0.211355          -0.625904
# Temperature in fer         -0.213985 -0.638061 -0.211355          -0.625904
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
df['Time']=pd.to_datetime(df['Time'])

# %%
df['month'] = pd.DatetimeIndex(df['Time']).month

# %%
data=df.loc[:,['District','Temperature in deg','Dew Point in Deg','Heat Index','month']]

# %%
data
# Out:
#       District  Temperature in deg  Dew Point in Deg  Heat Index  month
# 0     Adilabad                  38                -2   94.806511      4
# 1     Adilabad                  40                 3   98.663572      4
# 2     Adilabad                  41                 9  102.464666      4
# 3     Adilabad                  41                 9  102.464666      4
# 4     Adilabad                  37                11   96.010559      4
# ...        ...                 ...               ...         ...    ...
# 9130  Warangal                  25                23   78.243877      9
# 9131  Warangal                  26                22   81.705717      9
# 9132  Warangal                  27                22   84.575368      9
# 9133  Warangal                  28                23   88.263408      9
# 9134  Warangal                  27                23   85.328433      9
#
# [9135 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
data['District']=LE.fit_transform(data['District'])

# %%
data
# Out:
#       District  Temperature in deg  Dew Point in Deg  Heat Index  month
# 0            0                  38                -2   94.806511      4
# 1            0                  40                 3   98.663572      4
# 2            0                  41                 9  102.464666      4
# 3            0                  41                 9  102.464666      4
# 4            0                  37                11   96.010559      4
# ...        ...                 ...               ...         ...    ...
# 9130         3                  25                23   78.243877      9
# 9131         3                  26                22   81.705717      9
# 9132         3                  27                22   84.575368      9
# 9133         3                  28                23   88.263408      9
# 9134         3                  27                23   85.328433      9
#
# [9135 rows x 5 columns]

# %% [markdown]
# # Training Model

# %%
from sklearn.model_selection import train_test_split

# %%
X=data.drop(['Heat Index'],axis=1)

# %%
X
# Out:
#       District  Temperature in deg  Dew Point in Deg  month
# 0            0                  38                -2      4
# 1            0                  40                 3      4
# 2            0                  41                 9      4
# 3            0                  41                 9      4
# 4            0                  37                11      4
# ...        ...                 ...               ...    ...
# 9130         3                  25                23      9
# 9131         3                  26                22      9
# 9132         3                  27                22      9
# 9133         3                  28                23      9
# 9134         3                  27                23      9
#
# [9135 rows x 4 columns]

# %%
Y=data.loc[:,['Heat Index']]

# %%
Y
# Out:
#       Heat Index
# 0      94.806511
# 1      98.663572
# 2     102.464666
# 3     102.464666
# 4      96.010559
# ...          ...
# 9130   78.243877
# 9131   81.705717
# 9132   84.575368
# 9133   88.263408
# 9134   85.328433
#
# [9135 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,random_state=42,test_size=0.20)

# %%
x_train
# Out:
#       District  Temperature in deg  Dew Point in Deg  month
# 5123         2                  35                11      3
# 7738         3                  24                16     12
# 214          0                  29                22      8
# 8550         3                  39                16      5
# 7857         3                  27                12      2
# ...        ...                 ...               ...    ...
# 5734         4                  25                10     11
# 5191         2                  35                20      6
# 5390         2                  27                17     11
# 860          0                  28                22      7
# 7270         4                  26                 4      1
#
# [7308 rows x 4 columns]

# %%
y_train
# Out:
#       Heat Index
# 5123   92.272135
# 7738   77.437203
# 214    89.615980
# 8550  103.602490
# 7857   80.292468
# ...          ...
# 5734   78.170082
# 5191   99.853465
# 5390   81.843433
# 860    87.182811
# 7270   78.148722
#
# [7308 rows x 1 columns]

# %%
x_test
# Out:
#       District  Temperature in deg  Dew Point in Deg  month
# 708          0                  25                12      1
# 47           0                  39                -2      4
# 3995         2                  30                22     10
# 1513         0                  24                12     11
# 3686         2                  29                18     11
# ...        ...                 ...               ...    ...
# 4855         2                  27                10      1
# 1880         1                  37                 1      3
# 8473         3                  33                16      3
# 5967         4                  36                20      6
# 7971         3                  28                13      1
#
# [1827 rows x 4 columns]

# %%
y_test
# Out:
#       Heat Index
# 708    78.410597
# 47     96.320555
# 3995   91.940447
# 1513   77.700141
# 3686   85.722369
# ...          ...
# 4855   79.883300
# 1880   93.510139
# 8473   91.410218
# 5967  102.045792
# 7971   81.747130
#
# [1827 rows x 1 columns]

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LR.predict(x_test)

# %%
y_pred
# Out:
# array([[77.8392619 ],
#        [96.11930091],
#        [90.45142762],
#        ...,
#        [92.36086074],
#        [98.98576923],
#        [82.6874857 ]])

# %%
y_test.values
# Out:
# array([[ 78.4105968 ],
#        [ 96.32055453],
#        [ 91.94044657],
#        ...,
#        [ 91.41021771],
#        [102.0457922 ],
#        [ 81.74712988]])

# %%
LR.predict([[0,60,5,4]])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[133.85830936]])

# %%
LR.predict([[0,50,5,4]])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[117.16334412]])

# %% [markdown]
# ## Model Evaluation Random Forest Regressor

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
LR_R2=r2_score(y_test,y_pred)*100

# %%
print("R2 score:-",r2_score(y_test,y_pred)*100)
# Out:
# R2 score:- 94.17656693324163

# %%
LR_MAE=mean_absolute_error(y_test,y_pred)

# %%
print("mean_absolute_error:-",mean_absolute_error(y_test,y_pred))
# Out:
# mean_absolute_error:- 1.5371742246679396

# %%
LR_MSE=mean_squared_error(y_test,y_pred)

# %%
print("mean_squared_error:-",mean_squared_error(y_test,y_pred))
# Out:
# mean_squared_error:- 4.255245193201697

# %%
print("Training Score:-",LR.score(x_train,y_train)*100)
# Out:
# Training Score:- 94.00680946661326

# %%
print("Testing Score:-",LR.score(x_test,y_test)*100)
# Out:
# Testing Score:- 94.17656693324163

# %%
r2_score_LR=r2_score(y_test,y_pred)
N=len(y_test)
k=4
adj_r2_LR=(1-(1-r2_score_LR)*(N-1)/(N-k-1))
print("Adj_r2_LR:",adj_r2_LR*100)
# Out:
# Adj_r2_LR: 94.16378222837498

# %% [markdown]
# ## Rondom Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RFR=RandomForestRegressor()

# %%
RFR.fit(x_train,y_train)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10368\1229064473.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFR.fit(x_train,y_train)
# RandomForestRegressor()

# %%
y_pred=RFR.predict(x_test)

# %%
y_pred
# Out:
# array([ 78.4105968 ,  96.26709756,  91.94044657, ...,  91.30424613,
#        102.0457922 ,  81.74712988])

# %%
y_test.values
# Out:
# array([[ 78.4105968 ],
#        [ 96.32055453],
#        [ 91.94044657],
#        ...,
#        [ 91.41021771],
#        [102.0457922 ],
#        [ 81.74712988]])

# %% [markdown]
# ## Model Evaluation

# %%
RFR_R2=r2_score(y_test,y_pred)*100

# %%
print("R2 Score:-",r2_score(y_test,y_pred)*100)
# Out:
# R2 Score:- 99.98348385399753

# %%
RFR_MAE=mean_absolute_error(y_test,y_pred)

# %%
print("mean_absolute_error:-",mean_absolute_error(y_test,y_pred))
# Out:
# mean_absolute_error:- 0.014604738058206132

# %%
RFR_MSE=mean_squared_error(y_test,y_pred)

# %%
print("mean_squared_error:-",mean_squared_error(y_test,y_pred))
# Out:
# mean_squared_error:- 0.012068525572727357

# %%
print("Training Score:-",RFR.score(x_train,y_train)*100)
# Out:
# Training Score:- 99.99545572165704

# %%
print("Testing Score:-",RFR.score(x_test,y_test)*100)
# Out:
# Testing Score:- 99.98348385399753

# %%
r2_score_RFR=r2_score(y_test,y_pred)
N=len(y_test)
k=4
adj_r2_RFR=1-((1-r2_score_RFR)*(N-1)/(N-k-1))
print("Adj_r2_RFR:",adj_r2_RFR*100)
# Out:
# Adj_r2_RFR: 99.98344759462101

# %% [markdown]
# ## Prediction for sample values

# %%
RFR.predict([[0,43,15,4]])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([109.45929602])

# %% [markdown]
# ## SVR

# %%
from sklearn.svm import SVR
from scipy import stats

# %%
SVR=SVR()

# %%
SVR.fit(x_train,y_train)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
y_pred=SVR.predict(x_test)

# %%
y_pred
# Out:
# array([ 78.15191094,  96.34600664,  91.86827337, ...,  91.65021899,
#        102.31412566,  81.72840046])

# %%
y_test.values
# Out:
# array([[ 78.4105968 ],
#        [ 96.32055453],
#        [ 91.94044657],
#        ...,
#        [ 91.41021771],
#        [102.0457922 ],
#        [ 81.74712988]])

# %%
SVR.predict([[0,60,5,4]])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([112.3607677])

# %% [markdown]
# ## Model Evaluation

# %%
SVR_R2=r2_score(y_test,y_pred)*100

# %%
print("R2 score:-",r2_score(y_test,y_pred)*100)
# Out:
# R2 score:- 99.15071901518348

# %%
SVR_MAE=mean_absolute_error(y_test,y_pred)

# %%
print("mean_absolute_error:-",mean_absolute_error(y_test,y_pred))
# Out:
# mean_absolute_error:- 0.3810133029274017

# %%
SVR_MSE=mean_squared_error(y_test,y_pred)

# %%
print("mean_squared_error:-",mean_squared_error(y_test,y_pred))
# Out:
# mean_squared_error:- 0.6205787525827557

# %%
print("Training Score:-",SVR.score(x_train,y_train)*100)
# Out:
# Training Score:- 99.02676034885086

# %%
print("Test Score:-",SVR.score(x_test,y_test)*100)
# Out:
# Test Score:- 99.15071901518348

# %%
r2_score_SVR=r2_score(y_test,y_pred)
N=len(y_test)
k=4
adj_r2_SVR=(1-(1-r2_score_SVR)*(N-1)/(N-k-1))
print("Adj_r2_SVR:",adj_r2_SVR*100)
# Out:
# Adj_r2_SVR: 99.14885451247258

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
lasso=Lasso(alpha=0.0225)
lasso.fit(x_train,y_train)
y_pred1=lasso.predict(x_test)

# %%
lasso.predict([[0,50,5,4]])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# array([117.11962738])

# %% [markdown]
# ## Model Evaluation

# %%
LS_R2=r2_score(y_test,y_pred1)*100

# %%
r2=r2_score(y_test,y_pred1)

# %%
print("r2 score:-",r2*100)
# Out:
# r2 score:- 94.18069020504379

# %%
print('Train Score:',lasso.score(x_train,y_train)*100)
# Out:
# Train Score: 94.00632527258892

# %%
print('Test Score:',lasso.score(x_test,y_test)*100)
# Out:
# Test Score: 94.18069020504379

# %%
LS_MSE=mean_squared_error(y_test,y_pred1)

# %%
print('Mean Squared Error',mean_squared_error(y_test,y_pred1))
# Out:
# Mean Squared Error 4.252232274135707

# %%
LS_MAE=mean_absolute_error(y_test,y_pred1)

# %%
print("mean_absolute_error:-",mean_absolute_error(y_test,y_pred1))
# Out:
# mean_absolute_error:- 1.5368008146108654

# %%
r2_score_LS=r2_score(y_test,y_pred1)
N=len(y_test)
k=4
adj_r2_LS=(1-(1-r2_score_LS)*(N-1)/(N-k-1))
print("Adj_r2_LS:",adj_r2_LS*100)
# Out:
# Adj_r2_LS: 94.1679145523655

# %% [markdown]
# ## Neural Network

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from sklearn.metrics import r2_score
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(128, input_dim=12, activation='relu',input_shape = (4,)))

# %%
model.add(Dense(64, activation='tanh'))

# %%
model.add(Dense(1,activation='linear'))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
history=model.fit(x_train,y_train, validation_split=0.2, epochs = 60)
# Out:
# Epoch 1/60
# 183/183 [==============================] - 1s 2ms/step - loss: 5543.6211 - val_loss: 4657.7778
# Epoch 2/60
# 183/183 [==============================] - 0s 1ms/step - loss: 3941.9734 - val_loss: 3327.1067
# Epoch 3/60
# 183/183 [==============================] - 0s 1ms/step - loss: 2778.9343 - val_loss: 2314.9133
# Epoch 4/60
# 183/183 [==============================] - 0s 1ms/step - loss: 1905.3171 - val_loss: 1564.7747
# Epoch 5/60
# 183/183 [==============================] - 0s 1ms/step - loss: 1268.1508 - val_loss: 1027.3066
# Epoch 6/60
# 183/183 [==============================] - 0s 1ms/step - loss: 819.7558 - val_loss: 656.0274
# Epoch 7/60
# 183/183 [==============================] - 0s 1ms/step - loss: 517.3800 - val_loss: 411.4926
# Epoch 8/60
# 183/183 [==============================] - 0s 1ms/step - loss: 323.1725 - val_loss: 258.1065
# Epoch 9/60
# 183/183 [==============================] - 0s 1ms/step - loss: 205.4142 - val_loss: 168.0584
# Epoch 10/60
# ...

# %% [markdown]
# ## Model Evaluation

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
predictions = model.predict(x_test)
# Out:
# 58/58 [==============================] - 0s 609us/step

# %%
NN_R2=r2_score(y_test,predictions)*100

# %%
print("R2 score :", r2_score(y_test,predictions)*100)
# Out:
# R2 score : 99.65530217299391

# %%
NN_MAE=mean_absolute_error(y_test,predictions)

# %%
print("mean_absolute_error:-",mean_absolute_error(y_test,predictions))
# Out:
# mean_absolute_error:- 0.38069485288779176

# %%
NN_MSE=mean_squared_error(y_test,predictions)

# %%
print('Mean Squared Error',mean_squared_error(y_test,predictions))
# Out:
# Mean Squared Error 0.2518744106199918

# %%
r2_score_NN=r2_score(y_test,predictions)
N=len(y_test)
k=4
adj_r2_NN=(1-(1-r2_score_NN)*(N-1)/(N-k-1))
print("Adj_r2_NN:",adj_r2_NN*100)
# Out:
# Adj_r2_NN: 99.65454542694121

# %% [markdown]
# # HyperParameter Tunning For ANN

# %%
from sklearn.model_selection import GridSearchCV

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
def getModel(neurons1,neurons2):
    model = Sequential()
    model.add(Dense(neurons1, input_dim=12, activation='relu',input_shape = (4,)))
    model.add(Dense(neurons2, activation='tanh'))
    model.add(Dense(1,activation='linear'))
    model.compile(loss='mean_squared_error', optimizer='Adam')
    return model

# %%
neurons1=[1024,512,256,128]
neurons2=[1024,512,256,128]
epochs = [50,60,70,80]

# %%
param_grid = dict(epochs=epochs, neurons1=neurons1,neurons2=neurons2)

# %%
Kmodel = KerasClassifier(build_fn=getModel, verbose=1)
grid = GridSearchCV(estimator=Kmodel, param_grid=param_grid, scoring='neg_mean_absolute_percentage_error')
grid_result = grid.fit(x_train, y_train)
# Out:
# Epoch 1/50
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_21160\3699484364.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   Kmodel = KerasClassifier(build_fn=getModel, verbose=1)
# 183/183 [==============================] - 2s 11ms/step - loss: 43043.7227
# Epoch 2/50
# 183/183 [==============================] - 2s 11ms/step - loss: 17172.7148
# Epoch 3/50
# 183/183 [==============================] - 2s 11ms/step - loss: 11663.3076
# Epoch 4/50
# 183/183 [==============================] - 2s 11ms/step - loss: 6912.0864
# Epoch 5/50
# 183/183 [==============================] - 2s 11ms/step - loss: 3807.0015
# Epoch 6/50
# 183/183 [==============================] - 2s 11ms/step - loss: 2643.9414
# Epoch 7/50
# 183/183 [==============================] - 2s 11ms/step - loss: 1925.6027
# Epoch 8/50
# ...

# %%
grid_result.best_params_
# Out:
# {'epochs': 70, 'neurons1': 1024, 'neurons2': 128}

# %%
grid_result.best_score_
# Out:
# -0.2683382250848102

# %% [markdown]
# ## New ANN

# %%
getModel(1024,128)

# %%
history=model.fit(x_train,y_train, validation_split=0.2, epochs = 70)
# Out:
# Epoch 1/70
# 183/183 [==============================] - 0s 1ms/step - loss: 0.4218 - val_loss: 0.1725
# Epoch 2/70
# 183/183 [==============================] - 0s 1ms/step - loss: 0.4430 - val_loss: 0.2510
# Epoch 3/70
# 183/183 [==============================] - 0s 1ms/step - loss: 0.3365 - val_loss: 0.5242
# Epoch 4/70
# 183/183 [==============================] - 0s 1ms/step - loss: 0.3507 - val_loss: 0.8248
# Epoch 5/70
# 183/183 [==============================] - 0s 1ms/step - loss: 0.3486 - val_loss: 0.3911
# Epoch 6/70
# 183/183 [==============================] - 0s 1ms/step - loss: 0.2508 - val_loss: 0.3743
# Epoch 7/70
# 183/183 [==============================] - 0s 1ms/step - loss: 0.3599 - val_loss: 0.1991
# Epoch 8/70
# 183/183 [==============================] - 0s 1ms/step - loss: 0.2736 - val_loss: 0.1267
# Epoch 9/70
# 183/183 [==============================] - 0s 1ms/step - loss: 0.2360 - val_loss: 2.4095
# Epoch 10/70
# ...

# %%
predictions = model.predict(x_test)
# Out:
# 58/58 [==============================] - 0s 636us/step

# %% [markdown]
# ## Model Evaluation of ANN Regressor

# %%
NN_R2=r2_score(y_test,predictions)*100

# %%
print("R2 score :", r2_score(y_test,predictions)*100)
# Out:
# R2 score : 99.88678015557485

# %%
NN_MAE=mean_absolute_error(y_test,predictions)

# %%
print("mean_absolute_error:-",mean_absolute_error(y_test,predictions))
# Out:
# mean_absolute_error:- 0.22623061619934964

# %%
NN_MSE=mean_squared_error(y_test,predictions)

# %%
print('Mean Squared Error',mean_squared_error(y_test,predictions))
# Out:
# Mean Squared Error 0.08273095839552579

# %%
r2_score_NN=r2_score(y_test,predictions)
N=len(y_test)
k=4
adj_r2_NN=(1-(1-r2_score_NN)*(N-1)/(N-k-1))
print("Adj_r2_NN:",adj_r2_NN*100)
# Out:
# Adj_r2_NN: 99.88653159389665

# %%
Accuracy={"Linear Regression":LR_R2,"Neural Network":NN_R2,"SVR":SVR_R2,"Random Forest Regressor":RFR_R2,"Lasso Regression":LS_R2}

# %%
Accuracy
# Out:
# {'Linear Regression': 94.17656693324163,
#  'Neural Network': 99.88678015557485,
#  'SVR': 99.15071901518348,
#  'Random Forest Regressor': 99.98348385399753,
#  'Lasso Regression': 94.18069020504379}

# %%
Accuracy=pd.DataFrame(Accuracy,index=[0])

# %%
Accuracy
# Out:
#    Linear Regression  Neural Network        SVR  Random Forest Regressor  \
# 0          94.176567        99.88678  99.150719                99.983484
#
#    Lasso Regression
# 0          94.18069

# %% [markdown]
# # Visualization

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
ax=sns.barplot(data=Accuracy)
for i in  ax.containers:
    ax.bar_label(i,)
plt.title("R2 Score Comparison")
plt.show()

# %%
MAE={"Linear Regression":LR_MAE,"Neural Network":NN_MAE,"SVR":SVR_MAE,"Random Forest Regressor":RFR_MAE,"Lasso Regression":LS_MAE}

# %%
MAE
# Out:
# {'Linear Regression': 1.5371742246679396,
#  'Neural Network': 0.22623061619934964,
#  'SVR': 0.3810133029274017,
#  'Random Forest Regressor': 0.014604738058206132,
#  'Lasso Regression': 1.5368008146108654}

# %%
MAE=pd.DataFrame(MAE,index=[0])

# %%
plt.figure(figsize=(10,6))
ax=sns.barplot(data=MAE)
for i in  ax.containers:
    ax.bar_label(i,)
plt.title("MAE Comparison")
plt.show()

# %%
MSE={"Linear Regression":LR_MSE,"Neural Network":NN_MSE,"SVR":SVR_MSE,"Random Forest Regressor":RFR_MSE,"Lasso Regression":LS_MSE}

# %%
MSE
# Out:
# {'Linear Regression': 4.255245193201697,
#  'Neural Network': 0.08273095839552579,
#  'SVR': 0.6205787525827557,
#  'Random Forest Regressor': 0.012068525572727357,
#  'Lasso Regression': 4.252232274135707}

# %%
MSE=pd.DataFrame(MSE,index=[0])

# %%
plt.figure(figsize=(10,6))
ax=sns.barplot(data=MSE)
for i in  ax.containers:
    ax.bar_label(i,)
plt.title("MSE Comparison")
plt.show()

# %% [markdown]
# ## The End
